# %% [markdown]
# spaCy is a popular natural language processing library that provides efficient tools for various NLP tasks,
# including tokenization. It can tokenize text into words and sentences, making it easier to process and analyze text data.
# We can either create a blank pipeline or pre-trained pipeline using spaCy and perform tokenization process easily.

# %%
import spacy

# %%
content = ""
with open("./sample.txt","r") as f:
    content = f.read()
content
# Out:
# 'The names "John Doe" for males, "Jane Doe" or "Jane Roe" for females, or "Jonnie Doe" and "Janie Doe" for children, or just "Doe" non-gender-specifically are used as placeholder names for a party whose true identity is unknown or must be withheld in a legal action, case, or discussion. The names are also used to refer to acorpse or hospital patient whose identity is unknown. This practice is widely used in the United States and Canada, but is rarely used in other English-speaking countries including the United Kingdom itself, from where the use of "John Doe" in a legal context originates. The names Joe Bloggs or John Smith are used in the UK instead, as well as in Australia and New Zealand.\n\nJohn Doe is sometimes used to refer to a typical male in other contexts as well, in a similar manner to John Q. Public, known in Great Britain as Joe Public, John Smith or Joe Bloggs. For example, the first name listed on a form is often John Doe, along with a fictional address or other fictional information to provide an example of how to fill in the form. The name is also used frequently in popular culture, for example in the Frank Capra film Meet John Doe. John Doe was also the name of a 2002 American television series.\n\nSimilarly, a child or baby whose identity is unknown may be referred to as Baby Doe. A notorious murder case in Kansas City, Missouri, referred to the baby victim as Precious Doe. Other unidentified female murder victims are Cali Doe and Princess Doe. Additional persons may be called James Doe, Judy Doe, etc. However, to avoid possible confusion, if two anonymous or unknown parties are cited in a specific case or action, the surnames Doe and Roe may be used simultaneously; for example, "John Doe v. Jane Roe". If several anonymous parties are referenced, they may simply be labelled John Doe #1, John Doe #2, etc. (the U.S. Operation Delego cited 21 (numbered) "John Doe"s) or labelled with other variants of Doe / Roe / Poe / etc. Other early alternatives such as John Stiles and Richard Miles are now rarely used, and Mary Major has been used in some American federal cases.'

# %% [markdown]
# We can either create a blank pipeline or pre-trained pipeline using spaCy and perform tokenization process easily.
# Blank Pipeline: When you create a "blank" spaCy pipeline, you are initializing an instance of the spaCy language model without loading any pre-trained components. This can be useful if you want to add your own custom processing components or if you only need basic tokenization without advanced linguistic analysis.

# %% [markdown]
# ### Tokenization

# %%
NLP_blank = spacy.blank("en")
doc = NLP_blank(content)
tokens = [token for token in doc]
tokens
# Out:
# [The,
#  names,
#  ",
#  John,
#  Doe,
#  ",
#  for,
#  males,
#  ,,
#  ",
#  Jane,
#  Doe,
#  ",
#  or,
#  ",
#  Jane,
#  Roe,
#  ",
#  for,
#  females,
#  ,,
#  or,
#  ",
#  Jonnie,
#  Doe,
#  ",
#  and,
#  ",
#  Janie,
#  Doe,
#  ",
#  for,
#  children,
#  ,,
#  or,
#  just,
#  ",
#  Doe,
#  ",
#  non,
#  -,
#  gender,
#  -,
#  specifically,
#  are,
#  used,
#  as,
#  placeholder,
#  names,
#  for,
#  a,
#  party,
#  whose,
#  true,
#  identity,
#  is,
#  unknown,
#  or,
#  must,
#  be,
#  withheld,
#  in,
#  a,
#  legal,
#  action,
#  ,,
#  case,
#  ,,
#  or,
#  discussion,
#  .,
#  The,
#  names,
#  are,
#  also,
#  used,
#  to,
#  refer,
#  to,
#  acorpse,
#  or,
#  hospital,
#  patient,
#  whose,
#  identity,
#  is,
#  unknown,
#  .,
#  This,
#  practice,
#  is,
#  widely,
#  used,
#  in,
#  the,
#  United,
#  States,
#  and,
#  Canada,
#  ,,
#  but,
#  is,
#  rarely,
#  used,
#  in,
#  other,
#  English,
#  -,
#  speaking,
#  countries,
#  including,
#  the,
#  United,
#  Kingdom,
#  itself,
#  ,,
#  from,
#  where,
#  the,
#  use,
#  of,
#  ",
#  John,
#  Doe,
#  ",
#  in,
#  a,
#  legal,
#  context,
#  originates,
#  .,
#  The,
#  names,
#  Joe,
#  Bloggs,
#  or,
#  John,
#  Smith,
#  are,
#  used,
#  in,
#  the,
#  UK,
#  instead,
#  ,,
#  as,
#  well,
#  as,
#  in,
#  Australia,
#  and,
#  New,
#  Zealand,
#  .,
#
#  ,
#  John,
#  Doe,
#  is,
#  sometimes,
#  used,
#  to,
#  refer,
#  to,
#  a,
#  typical,
#  male,
#  in,
#  other,
#  contexts,
#  as,
#  well,
#  ,,
#  in,
#  a,
#  similar,
#  manner,
#  to,
#  John,
#  Q.,
#  Public,
#  ,,
#  known,
#  in,
#  Great,
#  Britain,
#  as,
#  Joe,
#  Public,
#  ,,
#  John,
#  Smith,
#  or,
#  Joe,
#  Bloggs,
#  .,
#  For,
#  example,
#  ,,
#  the,
#  first,
#  name,
#  listed,
#  on,
#  a,
#  form,
#  is,
#  often,
#  John,
#  Doe,
#  ,,
#  along,
#  with,
#  a,
#  fictional,
#  address,
#  or,
#  other,
#  fictional,
#  information,
#  to,
#  provide,
#  an,
#  example,
#  of,
#  how,
#  to,
#  fill,
#  in,
#  the,
#  form,
#  .,
#  The,
#  name,
#  is,
#  also,
#  used,
#  frequently,
#  in,
#  popular,
#  culture,
#  ,,
#  for,
#  example,
#  in,
#  the,
#  Frank,
#  Capra,
#  film,
#  Meet,
#  John,
#  Doe,
#  .,
#  John,
#  Doe,
#  was,
#  also,
#  the,
#  name,
#  of,
#  a,
#  2002,
#  American,
#  television,
#  series,
#  .,
#
#  ,
#  Similarly,
#  ,,
#  a,
#  child,
#  or,
#  baby,
#  whose,
#  identity,
#  is,
#  unknown,
#  may,
#  be,
#  referred,
#  to,
#  as,
#  Baby,
#  Doe,
#  .,
#  A,
#  notorious,
#  murder,
#  case,
#  in,
#  Kansas,
#  City,
#  ,,
#  Missouri,
#  ,,
#  referred,
#  to,
#  the,
#  baby,
#  victim,
#  as,
#  Precious,
#  Doe,
#  .,
#  Other,
#  unidentified,
#  female,
#  murder,
#  victims,
#  are,
#  Cali,
#  Doe,
#  and,
#  Princess,
#  Doe,
#  .,
#  Additional,
#  persons,
#  may,
#  be,
#  called,
#  James,
#  Doe,
#  ,,
#  Judy,
#  Doe,
#  ,,
#  etc,
#  .,
#  However,
#  ,,
#  to,
#  avoid,
#  possible,
#  confusion,
#  ,,
#  if,
#  two,
#  anonymous,
#  or,
#  unknown,
#  parties,
#  are,
#  cited,
#  in,
#  a,
#  specific,
#  case,
#  or,
#  action,
#  ,,
#  the,
#  surnames,
#  Doe,
#  and,
#  Roe,
#  may,
#  be,
#  used,
#  simultaneously,
#  ;,
#  for,
#  example,
#  ,,
#  ",
#  John,
#  Doe,
#  v.,
#  Jane,
#  Roe,
#  ",
#  .,
#  If,
#  several,
#  anonymous,
#  parties,
#  are,
#  referenced,
#  ,,
#  they,
#  may,
#  simply,
#  be,
#  labelled,
#  John,
#  Doe,
#  #,
#  1,
#  ,,
#  John,
#  Doe,
#  #,
#  2,
#  ,,
#  etc,
#  .,
#  (,
#  the,
#  U.S.,
#  Operation,
#  Delego,
#  cited,
#  21,
#  (,
#  numbered,
#  ),
#  ",
#  John,
#  Doe"s,
#  ),
#  or,
#  labelled,
#  with,
#  other,
#  variants,
#  of,
#  Doe,
#  /,
#  Roe,
#  /,
#  Poe,
#  /,
#  etc,
#  .,
#  Other,
#  early,
#  alternatives,
#  such,
#  as,
#  John,
#  Stiles,
#  and,
#  Richard,
#  Miles,
#  are,
#  now,
#  rarely,
#  used,
#  ,,
#  and,
#  Mary,
#  Major,
#  has,
#  been,
#  used,
#  in,
#  some,
#  American,
#  federal,
#  cases,
#  .]

# %% [markdown]
# ### Stemming

# %%
import nltk
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# %%
words = ['generous','generate','generously','generation','eating','eats','eaten','puts','putting','mass','was','bee','computer','advisable',"friend", "friendship", "friends", "friendships"]
for word in words:
    print(word , "=>" , stemmer.stem(word))
# Out:
# generous => gener
# generate => gener
# generously => gener
# generation => gener
# eating => eat
# eats => eat
# eaten => eaten
# puts => put
# putting => put
# mass => mass
# was => wa
# bee => bee
# computer => comput
# advisable => advis
# friend => friend
# friendship => friendship
# friends => friend
# friendships => friendship

# %% [markdown]
# ### Lemmatization

# %% [markdown]
# Pre-trained Pipeline: A pre-trained spaCy pipeline includes various linguistic components like part-of-speech tagging, named entity recognition, dependency parsing, and more, in addition to tokenization

# %%
NLP = spacy.load("en_core_web_sm")
str = " ".join(words)
str
doc = NLP(str)
for word in doc:
    print(word , "=>", word.lemma_)
# Out:
# generous => generous
# generate => generate
# generously => generously
# generation => generation
# eating => eat
# eats => eat
# eaten => eat
# puts => put
# putting => put
# mass => mass
# was => be
# bee => bee
# computer => computer
# advisable => advisable
# friend => friend
# friendship => friendship
# friends => friend
# friendships => friendship

# %% [markdown]
# ### POS Tagging

# %%
doc = NLP(content)
for token in doc: 
    print(token, "=>", token.pos_ ,f"({spacy.explain(token.pos_)})")
# Out:
# The => DET (determiner)
# names => NOUN (noun)
# " => PUNCT (punctuation)
# John => PROPN (proper noun)
# Doe => PROPN (proper noun)
# " => PUNCT (punctuation)
# for => ADP (adposition)
# males => NOUN (noun)
# , => PUNCT (punctuation)
# " => PUNCT (punctuation)
# Jane => PROPN (proper noun)
# Doe => PROPN (proper noun)
# " => PUNCT (punctuation)
# or => CCONJ (coordinating conjunction)
# " => PUNCT (punctuation)
# Jane => PROPN (proper noun)
# Roe => PROPN (proper noun)
# " => PUNCT (punctuation)
# for => ADP (adposition)
# females => NOUN (noun)
# , => PUNCT (punctuation)
# or => CCONJ (coordinating conjunction)
# " => PUNCT (punctuation)
# Jonnie => PROPN (proper noun)
# Doe => PROPN (proper noun)
# " => PUNCT (punctuation)
# and => CCONJ (coordinating conjunction)
# " => PUNCT (punctuation)
# Janie => PROPN (proper noun)
# Doe => PROPN (proper noun)
# " => PUNCT (punctuation)
# for => ADP (adposition)
# children => NOUN (noun)
# , => PUNCT (punctuation)
# or => CCONJ (coordinating conjunction)
# just => ADV (adverb)
# " => PUNCT (punctuation)
# Doe => PROPN (proper noun)
# " => PUNCT (punctuation)
# non => ADJ (adjective)
# - => ADJ (adjective)
# gender => NOUN (noun)
# - => PUNCT (punctuation)
# specifically => ADV (adverb)
# are => AUX (auxiliary)
# used => VERB (verb)
# as => ADP (adposition)
# placeholder => NOUN (noun)
# names => NOUN (noun)
# for => ADP (adposition)
# a => DET (determiner)
# party => NOUN (noun)
# whose => DET (determiner)
# true => ADJ (adjective)
# identity => NOUN (noun)
# is => AUX (auxiliary)
# unknown => ADJ (adjective)
# or => CCONJ (coordinating conjunction)
# must => AUX (auxiliary)
# be => AUX (auxiliary)
# withheld => VERB (verb)
# in => ADP (adposition)
# a => DET (determiner)
# legal => ADJ (adjective)
# action => NOUN (noun)
# , => PUNCT (punctuation)
# case => NOUN (noun)
# , => PUNCT (punctuation)
# or => CCONJ (coordinating conjunction)
# discussion => NOUN (noun)
# . => PUNCT (punctuation)
# The => DET (determiner)
# names => NOUN (noun)
# are => AUX (auxiliary)
# also => ADV (adverb)
# used => VERB (verb)
# to => PART (particle)
# refer => VERB (verb)
# to => ADP (adposition)
# acorpse => NOUN (noun)
# or => CCONJ (coordinating conjunction)
# hospital => NOUN (noun)
# patient => NOUN (noun)
# whose => DET (determiner)
# identity => NOUN (noun)
# is => AUX (auxiliary)
# unknown => ADJ (adjective)
# . => PUNCT (punctuation)
# This => DET (determiner)
# practice => NOUN (noun)
# is => AUX (auxiliary)
# widely => ADV (adverb)
# used => VERB (verb)
# in => ADP (adposition)
# the => DET (determiner)
# United => PROPN (proper noun)
# States => PROPN (proper noun)
# and => CCONJ (coordinating conjunction)
# Canada => PROPN (proper noun)
# , => PUNCT (punctuation)
# but => CCONJ (coordinating conjunction)
# is => AUX (auxiliary)
# rarely => ADV (adverb)
# used => VERB (verb)
# in => ADP (adposition)
# other => ADJ (adjective)
# English => PROPN (proper noun)
# - => PUNCT (punctuation)
# speaking => VERB (verb)
# countries => NOUN (noun)
# including => VERB (verb)
# the => DET (determiner)
# United => PROPN (proper noun)
# Kingdom => PROPN (proper noun)
# itself => PRON (pronoun)
# , => PUNCT (punctuation)
# from => ADP (adposition)
# where => SCONJ (subordinating conjunction)
# the => DET (determiner)
# use => NOUN (noun)
# of => ADP (adposition)
# " => PUNCT (punctuation)
# John => PROPN (proper noun)
# Doe => PROPN (proper noun)
# " => PUNCT (punctuation)
# in => ADP (adposition)
# a => DET (determiner)
# legal => ADJ (adjective)
# context => NOUN (noun)
# originates => NOUN (noun)
# . => PUNCT (punctuation)
# The => DET (determiner)
# names => NOUN (noun)
# Joe => PROPN (proper noun)
# Bloggs => PROPN (proper noun)
# or => CCONJ (coordinating conjunction)
# John => PROPN (proper noun)
# Smith => PROPN (proper noun)
# are => AUX (auxiliary)
# used => VERB (verb)
# in => ADP (adposition)
# the => DET (determiner)
# UK => PROPN (proper noun)
# instead => ADV (adverb)
# , => PUNCT (punctuation)
# as => ADV (adverb)
# well => ADV (adverb)
# as => ADP (adposition)
# in => ADP (adposition)
# Australia => PROPN (proper noun)
# and => CCONJ (coordinating conjunction)
# New => PROPN (proper noun)
# Zealand => PROPN (proper noun)
# . => PUNCT (punctuation)
#
#
#  => SPACE (space)
# John => PROPN (proper noun)
# Doe => PROPN (proper noun)
# is => AUX (auxiliary)
# sometimes => ADV (adverb)
# used => VERB (verb)
# to => PART (particle)
# refer => VERB (verb)
# to => ADP (adposition)
# a => DET (determiner)
# typical => ADJ (adjective)
# male => NOUN (noun)
# in => ADP (adposition)
# other => ADJ (adjective)
# contexts => NOUN (noun)
# as => ADV (adverb)
# well => ADV (adverb)
# , => PUNCT (punctuation)
# in => ADP (adposition)
# a => DET (determiner)
# similar => ADJ (adjective)
# manner => NOUN (noun)
# to => ADP (adposition)
# John => PROPN (proper noun)
# Q. => PROPN (proper noun)
# Public => PROPN (proper noun)
# , => PUNCT (punctuation)
# known => VERB (verb)
# in => ADP (adposition)
# Great => PROPN (proper noun)
# Britain => PROPN (proper noun)
# as => ADP (adposition)
# Joe => PROPN (proper noun)
# Public => PROPN (proper noun)
# , => PUNCT (punctuation)
# John => PROPN (proper noun)
# Smith => PROPN (proper noun)
# or => CCONJ (coordinating conjunction)
# Joe => PROPN (proper noun)
# Bloggs => PROPN (proper noun)
# . => PUNCT (punctuation)
# For => ADP (adposition)
# example => NOUN (noun)
# , => PUNCT (punctuation)
# the => DET (determiner)
# first => ADJ (adjective)
# name => NOUN (noun)
# listed => VERB (verb)
# on => ADP (adposition)
# a => DET (determiner)
# form => NOUN (noun)
# is => AUX (auxiliary)
# often => ADV (adverb)
# John => PROPN (proper noun)
# Doe => PROPN (proper noun)
# , => PUNCT (punctuation)
# along => ADP (adposition)
# with => ADP (adposition)
# a => DET (determiner)
# fictional => ADJ (adjective)
# address => NOUN (noun)
# or => CCONJ (coordinating conjunction)
# other => ADJ (adjective)
# fictional => ADJ (adjective)
# information => NOUN (noun)
# to => PART (particle)
# provide => VERB (verb)
# an => DET (determiner)
# example => NOUN (noun)
# of => ADP (adposition)
# how => SCONJ (subordinating conjunction)
# to => PART (particle)
# fill => VERB (verb)
# in => ADP (adposition)
# the => DET (determiner)
# form => NOUN (noun)
# . => PUNCT (punctuation)
# The => DET (determiner)
# name => NOUN (noun)
# is => AUX (auxiliary)
# also => ADV (adverb)
# used => VERB (verb)
# frequently => ADV (adverb)
# in => ADP (adposition)
# popular => ADJ (adjective)
# culture => NOUN (noun)
# , => PUNCT (punctuation)
# for => ADP (adposition)
# example => NOUN (noun)
# in => ADP (adposition)
# the => DET (determiner)
# Frank => PROPN (proper noun)
# Capra => PROPN (proper noun)
# film => NOUN (noun)
# Meet => PROPN (proper noun)
# John => PROPN (proper noun)
# Doe => PROPN (proper noun)
# . => PUNCT (punctuation)
# John => PROPN (proper noun)
# Doe => PROPN (proper noun)
# was => AUX (auxiliary)
# also => ADV (adverb)
# the => DET (determiner)
# name => NOUN (noun)
# of => ADP (adposition)
# a => DET (determiner)
# 2002 => NUM (numeral)
# American => ADJ (adjective)
# television => NOUN (noun)
# series => NOUN (noun)
# . => PUNCT (punctuation)
#
#
#  => SPACE (space)
# Similarly => ADV (adverb)
# , => PUNCT (punctuation)
# a => DET (determiner)
# child => NOUN (noun)
# or => CCONJ (coordinating conjunction)
# baby => NOUN (noun)
# whose => DET (determiner)
# identity => NOUN (noun)
# is => AUX (auxiliary)
# unknown => ADJ (adjective)
# may => AUX (auxiliary)
# be => AUX (auxiliary)
# referred => VERB (verb)
# to => ADP (adposition)
# as => ADP (adposition)
# Baby => PROPN (proper noun)
# Doe => PROPN (proper noun)
# . => PUNCT (punctuation)
# A => DET (determiner)
# notorious => ADJ (adjective)
# murder => NOUN (noun)
# case => NOUN (noun)
# in => ADP (adposition)
# Kansas => PROPN (proper noun)
# City => PROPN (proper noun)
# , => PUNCT (punctuation)
# Missouri => PROPN (proper noun)
# , => PUNCT (punctuation)
# referred => VERB (verb)
# to => ADP (adposition)
# the => DET (determiner)
# baby => NOUN (noun)
# victim => NOUN (noun)
# as => ADP (adposition)
# Precious => ADJ (adjective)
# Doe => PROPN (proper noun)
# . => PUNCT (punctuation)
# Other => ADJ (adjective)
# unidentified => ADJ (adjective)
# female => ADJ (adjective)
# murder => NOUN (noun)
# victims => NOUN (noun)
# are => AUX (auxiliary)
# Cali => PROPN (proper noun)
# Doe => PROPN (proper noun)
# and => CCONJ (coordinating conjunction)
# Princess => PROPN (proper noun)
# Doe => PROPN (proper noun)
# . => PUNCT (punctuation)
# Additional => ADJ (adjective)
# persons => NOUN (noun)
# may => AUX (auxiliary)
# be => AUX (auxiliary)
# called => VERB (verb)
# James => PROPN (proper noun)
# Doe => PROPN (proper noun)
# , => PUNCT (punctuation)
# Judy => PROPN (proper noun)
# Doe => PROPN (proper noun)
# , => PUNCT (punctuation)
# etc => X (other)
# . => X (other)
# However => ADV (adverb)
# , => PUNCT (punctuation)
# to => PART (particle)
# avoid => VERB (verb)
# possible => ADJ (adjective)
# confusion => NOUN (noun)
# , => PUNCT (punctuation)
# if => SCONJ (subordinating conjunction)
# two => NUM (numeral)
# anonymous => ADJ (adjective)
# or => CCONJ (coordinating conjunction)
# unknown => ADJ (adjective)
# parties => NOUN (noun)
# are => AUX (auxiliary)
# cited => VERB (verb)
# in => ADP (adposition)
# a => DET (determiner)
# specific => ADJ (adjective)
# case => NOUN (noun)
# or => CCONJ (coordinating conjunction)
# action => NOUN (noun)
# , => PUNCT (punctuation)
# the => DET (determiner)
# surnames => NOUN (noun)
# Doe => PROPN (proper noun)
# and => CCONJ (coordinating conjunction)
# Roe => PROPN (proper noun)
# may => AUX (auxiliary)
# be => AUX (auxiliary)
# used => VERB (verb)
# simultaneously => ADV (adverb)
# ; => PUNCT (punctuation)
# for => ADP (adposition)
# example => NOUN (noun)
# , => PUNCT (punctuation)
# " => PUNCT (punctuation)
# John => PROPN (proper noun)
# Doe => PROPN (proper noun)
# v. => ADP (adposition)
# Jane => PROPN (proper noun)
# Roe => PROPN (proper noun)
# " => PUNCT (punctuation)
# . => PUNCT (punctuation)
# If => SCONJ (subordinating conjunction)
# several => ADJ (adjective)
# anonymous => ADJ (adjective)
# parties => NOUN (noun)
# are => AUX (auxiliary)
# referenced => VERB (verb)
# , => PUNCT (punctuation)
# they => PRON (pronoun)
# may => AUX (auxiliary)
# simply => ADV (adverb)
# be => AUX (auxiliary)
# labelled => VERB (verb)
# John => PROPN (proper noun)
# Doe => PROPN (proper noun)
# # => SYM (symbol)
# 1 => NUM (numeral)
# , => PUNCT (punctuation)
# John => PROPN (proper noun)
# Doe => PROPN (proper noun)
# # => SYM (symbol)
# 2 => NUM (numeral)
# , => PUNCT (punctuation)
# etc => X (other)
# . => X (other)
# ( => PUNCT (punctuation)
# the => DET (determiner)
# U.S. => PROPN (proper noun)
# Operation => PROPN (proper noun)
# Delego => PROPN (proper noun)
# cited => VERB (verb)
# 21 => NUM (numeral)
# ( => PUNCT (punctuation)
# numbered => VERB (verb)
# ) => PUNCT (punctuation)
# " => PUNCT (punctuation)
# John => PROPN (proper noun)
# Doe"s => PROPN (proper noun)
# ) => PUNCT (punctuation)
# or => CCONJ (coordinating conjunction)
# labelled => VERB (verb)
# with => ADP (adposition)
# other => ADJ (adjective)
# variants => NOUN (noun)
# of => ADP (adposition)
# Doe => PROPN (proper noun)
# / => SYM (symbol)
# Roe => PROPN (proper noun)
# / => SYM (symbol)
# Poe => PROPN (proper noun)
# / => PUNCT (punctuation)
# etc => X (other)
# . => PUNCT (punctuation)
# Other => ADJ (adjective)
# early => ADJ (adjective)
# alternatives => NOUN (noun)
# such => ADJ (adjective)
# as => ADP (adposition)
# John => PROPN (proper noun)
# Stiles => PROPN (proper noun)
# and => CCONJ (coordinating conjunction)
# Richard => PROPN (proper noun)
# Miles => PROPN (proper noun)
# are => AUX (auxiliary)
# now => ADV (adverb)
# rarely => ADV (adverb)
# used => VERB (verb)
# , => PUNCT (punctuation)
# and => CCONJ (coordinating conjunction)
# Mary => PROPN (proper noun)
# Major => PROPN (proper noun)
# has => AUX (auxiliary)
# been => AUX (auxiliary)
# used => VERB (verb)
# in => ADP (adposition)
# some => DET (determiner)
# American => ADJ (adjective)
# federal => ADJ (adjective)
# cases => NOUN (noun)
# . => PUNCT (punctuation)
